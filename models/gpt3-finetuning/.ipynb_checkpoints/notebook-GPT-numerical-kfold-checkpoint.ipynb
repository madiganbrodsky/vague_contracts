# %%
import openai
import os
import pandas
import numpy as np
openai.api_key = os.getenv("OPENAI_API_KEY")
np.random.seed(1)

# %%
d = pandas.read_csv("../../results/1_falseconsensus/fineTuneDataSet.csv")
d.head(1) 
# prompts.head(1)
# Out:
#                  title        version  nYes  nNo  nCantDecide   propYes  \
# 0  Emergency Damages I  controversial    24    7            4  0.685714
#
#    propNo  propCantDecide               item  \
# 0     0.2        0.114286  Emergency Damages
#
#                                               header  \
# 0  Joanne's home insurance covers "Emergency Dama...
#
#                                         continuation
# 0  Late one night, Joanne hears loud crashing noi...

# %%
d["question"] = "Out of 100 randomly-surveyed people, estimate how many would believe that the claim described in the TEXT is covered under " + d.item + "as it appears in the policy."

# %%
d["promptNoExample"] = d.question + "TEXT: " + d.header + d.continuation + "\n" + "ESTIMATE (out of 100): " + "\n\n###\n\n"

# %%
d["completion"] = np.around(d.propYes * 100).astype(int).astype(str)
d.head(1)
# Out:
#                  title        version  nYes  nNo  nCantDecide   propYes  \
# 0  Emergency Damages I  controversial    24    7            4  0.685714
#
#    propNo  propCantDecide               item  \
# 0     0.2        0.114286  Emergency Damages
#
#                                               header  \
# 0  Joanne's home insurance covers "Emergency Dama...
#
#                                         continuation  \
# 0  Late one night, Joanne hears loud crashing noi...
#
#                                             question  \
# 0  Out of 100 randomly-surveyed people, estimate ...
#
#                                               prompt completion
# 0  Joanne's home insurance covers "Emergency Dama...         69

# %%
# GET UNTUNED PREDICTIONS
d["untunedPredictions"] = d.apply(lambda x : openai.Completion.create(model="text-davinci-003", 
                                    prompt=x["promptNoExample"],
                                    temperature=0, max_tokens=4).choices[0].text, axis = 1)

# %%
# CREATE 12 RANDOM FOLDS OF EXAMPLES 
d["index"] = np.arange(len(d))
fewShotFoldIndices = np.copy(d.index)
np.random.shuffle(fewShotFoldIndices)
fewShotFolds = np.array_split(fewShotFoldIndices, 12)

# %%
createExample = lambda x : "\n --- \n TEXT: " + d["header"][x] + d["continuation"][x] + "\n" + d.question + "\n" + "ESTIMATE (out of 100): " + d["completion"][x]
d["promptWithExampleSet1"] = createExample(fewShotFolds[0]).str.cat() + "TEXT: " + d.header + d.continuation + "\n" + d.question + "\n" + "ESTIMATE (out of 100): "
d["promptWithExampleSet2"] = createExample(fewShotFolds[1]).str.cat() + "TEXT: " + d.header + d.continuation + "\n" + d.question + "\n" + "ESTIMATE (out of 100): "
d["promptWithExampleSet3"] = createExample(fewShotFolds[2]).str.cat() + "TEXT: " + d.header + d.continuation + "\n" + d.question + "\n" + "ESTIMATE (out of 100): "
d["promptWithExampleSet4"] = createExample(fewShotFolds[3]).str.cat() + "TEXT: " + d.header + d.continuation + "\n" + d.question + "\n" + "ESTIMATE (out of 100): "
d["promptWithExampleSet5"] = createExample(fewShotFolds[4]).str.cat() + "TEXT: " + d.header + d.continuation + "\n" + d.question + "\n" + "ESTIMATE (out of 100): "

# %%
d["fewShotPredictions1"] = d.apply(lambda x : openai.Completion.create(model="text-davinci-003", 
                                    prompt=x["promptWithExampleSet1"],
                                    temperature=0, max_tokens=4).choices[0].text, axis = 1)
d["fewShotPredictions2"] = d.apply(lambda x : openai.Completion.create(model="text-davinci-003", 
                                    prompt=x["promptWithExampleSet2"],
                                    temperature=0, max_tokens=4).choices[0].text, axis = 1)
d["fewShotPredictions3"] = d.apply(lambda x : openai.Completion.create(model="text-davinci-003", 
                                    prompt=x["promptWithExampleSet3"],
                                    temperature=0, max_tokens=4).choices[0].text, axis = 1)
d["fewShotPredictions4"] = d.apply(lambda x : openai.Completion.create(model="text-davinci-003", 
                                    prompt=x["promptWithExampleSet4"],
                                    temperature=0, max_tokens=4).choices[0].text, axis = 1)
d["fewShotPredictions5"] = d.apply(lambda x : openai.Completion.create(model="text-davinci-003", 
                                    prompt=x["promptWithExampleSet5"],
                                    temperature=0, max_tokens=4).choices[0].text, axis = 1)

# %%
d["promptWithExampleSet1"][0]
# Out:
# '\n --- \n TEXT: Joanne\'s home insurance covers "Emergency Damages," defined as <b>"loss or damage to the contents of the policyholder\'s home caused when first responders force an entry into the policyholder\'s home because of an emergency or perceived emergency involving the policyholder."</b>Late one night, Joanne hears loud crashing noises coming from another room in her home and knows it is just her two dogs playing together. From her bedroom, she frantically calls the police, who make a forced entry into her home to assess the situation. It turns out that the noises Joanne heard were indeed from her dogs; Joanne just wanted help subduing the dogs. Joanne files a claim with her insurance company for the damage caused by the forced entry.\nOut of 100 randomly-surveyed people, estimate how many would believe that the claim described in the text is covered under Emergency Damagesas it appears in the policy.\nESTIMATE (out of 100): 42\n --- \n TEXT: Madison has insurance that covers home damage from "Escape of Oil," defined as <b>"oil leaking from a fixed oil-fired heating installation."</b>As Madison is carrying kerosene oil through her kitchen one afternoon, she slips and spills the oil, damaging her hardwood floors. Madison files a claim with her insurance company for the damage.\nOut of 100 randomly-surveyed people, estimate how many would believe that the claim described in the text is covered under Escape of Oilas it appears in the policy.\nESTIMATE (out of 100): 7\n --- \n TEXT: Mariam has insurance that covers home damage from "Escape of Oil," defined as <b>"oil leaking from a fixed oil-fired heating installation."</b>Mariam has a fixed oil-fired heater in her living room. One night, the heater cracks and leaks oil onto the carpet. The oil then seeps into the floor and causes significant damage. Mariam files a claim with her insurance company for the damage.\nOut of 100 randomly-surveyed people, estimate how many would believe that the claim described in the text is covered under Escape of Oilas it appears in the policy.\nESTIMATE (out of 100): 100\n --- \n TEXT: Gavin has an insurance policy that includes coverage for "General Damages," which includes losses from <b>"missed employment due to injuries that occur under regular working conditions."</b>Gavin works as an A/C repair technician in a small town. One day, Gavin is hired to repair an air conditioner located on the second story of a building. Because Gavin is an experienced repairman, he knows that the safest way to access the unit is with a sturdy ladder. While climbing the ladder, Gavin loses his balance and falls, causing significant injury. Because of this, he subsequently has to stop working for weeks. Gavin files a claim with his insurance company for lost income.\nOut of 100 randomly-surveyed people, estimate how many would believe that the claim described in the text is covered under General Damagesas it appears in the policy.\nESTIMATE (out of 100): 100\n --- \n TEXT: Denise\'s insurance covers damage from "House Removal," defined as <b>"damage to belongings caused while being removed by professional removal contractors from the home."</b>Denise is moving to a new home on the other side of town. She rents a truck and decides she will move her own belongings out of her current home. During the move, her truck is involved in a minor accident that damages several pieces of her furniture and other belongings. Denise files a claim with her insurance company for the damage to her belongings.\nOut of 100 randomly-surveyed people, estimate how many would believe that the claim described in the text is covered under House Removalas it appears in the policy.\nESTIMATE (out of 100): 21\n --- \n TEXT: Jason has insurance coverage against loss and damage from "Identity Theft," which excludes <b>"identity theft connected with the policyholder\'s business."</b>Jason is a successful car salesman. One day, while Jason is at home, hackers manage to infiltrate Jason\'s  ...

# %%
np.corrcoef(d.completion.astype(int),d.fewShotPredictions1.astype(int))
# Out:
# array([[1.        , 0.56631505],
#        [0.56631505, 1.        ]])

# %%
# CORRELATION COEFFICIENT OF UNTUNED PREDICTIONS AGAINST OBSERVATIONS
np.corrcoef(d.completion.astype(int),d.untunedPredictions.astype(int))

# %%
# CREATE 10 FOLDS 
d["index"] = np.arange(len(d))
foldIndices = np.copy(d.index)
np.random.shuffle(foldIndices)
folds = np.array_split(foldIndices, 10)

# %%
fineTuneRecords = pandas.DataFrame(data = {"fold" : [], "file": [], "model": []})

# %%
for i in range(0,1):
    trainSet = d[~(np.isin(d["index"],folds[i]))]
    #https://beta.openai.com/docs/guides/fine-tuning/preparing-your-dataset
    trainSet["completion"] = " " + trainSet["completion"] + " END"
    fileCreateCallBack = openai.File.create(
        file=trainSet.to_json(orient = "records", lines=True),
        purpose='fine-tune'
    )
    fineTuneCreateCallBack = openai.FineTune.create(
        training_file=fileCreateCallBack.id, 
        model = "davinci",
        n_epochs = 10,
        learning_rate_multiplier = 0.02,
        batch_size = 1
    )
    fineTuneRecords = fineTuneRecords.append({"fold": i, "file": fileCreateCallBack.id, "model": fineTuneCreateCallBack.id}, ignore_index = True)
# Out:
# /var/folders/f3/n7fhwntd1_l2fcjc2pcmf4wm0000gn/T/ipykernel_23904/522607929.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trainSet["completion"] = " " + trainSet["completion"] + " END"
# /var/folders/f3/n7fhwntd1_l2fcjc2pcmf4wm0000gn/T/ipykernel_23904/522607929.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fineTuneRecords = fineTuneRecords.append({"fold": i, "file": fileCreateCallBack.id, "model": fineTuneCreateCallBack.id}, ignore_index = True)

# %%
fineTuneRecords
# Out:
#    fold                           file                        model
# 0   0.0  file-39fEIDE0qJQWIRhXdpIgni4m  ft-DvEQfdlTCK2AjdyJHoeab98J
# 1   0.0  file-37fV9BSTrMYOkciT8gNU6Tyh  ft-s2FJFKTZ9KD9ZUGd5t18IRUS
# 2   0.0  file-RWz3mcmL43u3QIyEYrzGvvMe  ft-HSgEG5W1rFoQlBtY8RFQVRqF
# 3   0.0  file-m1hRA0D3QKR1xv2RKOSj6qRw  ft-glTAdPkXDETZOP2A9VmjHHbC

# %%
openai.FineTune.retrieve("ft-glTAdPkXDETZOP2A9VmjHHbC")
# Out:
# <FineTune fine-tune id=ft-glTAdPkXDETZOP2A9VmjHHbC at 0x1198e5670> JSON: {
#   "created_at": 1674598833,
#   "events": [
#     {
#       "created_at": 1674598833,
#       "level": "info",
#       "message": "Created fine-tune: ft-glTAdPkXDETZOP2A9VmjHHbC",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599166,
#       "level": "info",
#       "message": "Fine-tune costs $6.09",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599167,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599170,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599353,
#       "level": "info",
#       "message": "Completed epoch 1/10",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599396,
#       "level": "info",
#       "message": "Completed epoch 2/10",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599444,
#       "level": "info",
#       "message": "Completed epoch 3/10",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599488,
#       "level": "info",
#       "message": "Completed epoch 4/10",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599532,
#       "level": "info",
#       "message": "Completed epoch 5/10",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599575,
#       "level": "info",
#       "message": "Completed epoch 6/10",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599619,
#       "level": "info",
#       "message": "Completed epoch 7/10",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599663,
#       "level": "info",
#       "message": "Completed epoch 8/10",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599706,
#       "level": "info",
#       "message": "Completed epoch 9/10",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599755,
#       "level": "info",
#       "message": "Completed epoch 10/10",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599790,
#       "level": "info",
#       "message": "Uploaded model: davinci:ft-stanford-2023-01-24-22-36-29",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599794,
#       "level": "info",
#       "message": "Uploaded result file: file-TRTL2RMiNrRUEvUWJ4ReQGu7",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1674599795,
#       "level": "info",
#       "message": "Fine-tune succeeded",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": "davinci:ft-stanford-2023-01-24-22-36-29",
#   "hyperparams": {
#     "batch_size": 1,
#     "learning_rate_multiplier": 0.02,
#     "n_epochs": 10,
#     "prompt_loss_weight": 0.01
#   },
#   "id": "ft-glTAdPkXDETZOP2A9VmjHHbC",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-O1nE8SHl8ANRhiZJ3M17aIt6",
#   "result_files": [
#     {
#       "bytes": 53517,
#       "created_at": 1674599792,
#       "filename": "compiled_results.csv",
#       "id": "file-TRTL2RMiNrRUEvUWJ4ReQGu7",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "status": "succeeded",
#   "training_files": [
#     {
#       "bytes": 210685,
#       "created_at": 1674598832,
#       "filename": "file",
#       "id": "file-m1hRA0D3QKR1xv2RKOSj6qRw",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1674599796,
#   "validation_files": []
# }

# %%
testSet = d[np.isin(d["index"],folds[0])]
testSet["fineTunedPredictions"] = testSet.apply(lambda x : openai.Completion.create(model="davinci:ft-stanford-2023-01-24-22-15-27", 
                                    prompt=x["prompt"],
                                    stop=[" END"],                                          
                                    temperature=0, max_tokens=4).choices[0].text, axis = 1)
# Out:
# /var/folders/f3/n7fhwntd1_l2fcjc2pcmf4wm0000gn/T/ipykernel_23904/2015593144.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testSet["fineTunedPredictions"] = testSet.apply(lambda x : openai.Completion.create(model="davinci:ft-stanford-2023-01-24-22-15-27",

# %%
# 44, 5, 19

openai.Completion.create(model="davinci:ft-stanford-2023-01-24-22-36-29", 
                                    prompt=testSet["prompt"][5],
                                    stop=" END",                                          
                                    temperature=0, max_tokens=4).choices[0].text
# Out:
# ' 100'

# %%
# openai.Completion.create(model="davinci:ft-stanford-2023-01-24-20-01-04", 
#                                     prompt=testSet["prompt"],
#                                     temperature=0, max_tokens=4).choices[0]

# %%
testSet
# Out:
#                               title                version  nYes  nNo  \
# 5              Emergency Damages II  unambiguous_uncovered     2   24
# 19              Escape of Water III    unambiguous_covered    27    4
# 33                 Garden Plants II          controversial    28    2
# 35                 Garden Plants II  unambiguous_uncovered     7   24
# 36                  General Damages          controversial     8   26
# 44                   Ground Heave I  unambiguous_uncovered     8   35
# 54                      Hot Work II          controversial    16    9
# 59                  House Removal I  unambiguous_uncovered     5   18
# 77   Malicious Acts or Vandalism II  unambiguous_uncovered     1   24
# 83             Personal Accident II  unambiguous_uncovered    14   14
# 90               Trace and Access I          controversial    15    4
# 91               Trace and Access I    unambiguous_covered    22    6
# 122                Vehicle Glass II  unambiguous_uncovered     2   26
# 134                Vehicle Theft VI  unambiguous_uncovered     0   22
#
#      nCantDecide   propYes    propNo  propCantDecide  \
# 5              4  0.066667  0.800000        0.133333
# 19             0  0.870968  0.129032        0.000000
# 33             0  0.933333  0.066667        0.000000
# 35             2  0.212121  0.727273        0.060606
# 36             1  0.228571  0.742857        0.028571
# 44             4  0.170213  0.744681        0.085106
# 54             2  0.592593  0.333333        0.074074
# 59             1  0.208333  0.750000        0.041667
# 77             2  0.037037  0.888889        0.074074
# 83             1  0.482759  0.482759        0.034483
# 90             2  0.714286  0.190476        0.095238
# 91             2  0.733333  0.200000        0.066667
# 122            0  0.071429  0.928571        0.000000
# 134            0  0.000000  1.000000        0.000000
#
#                             item  \
# 5              Emergency Damages
# 19               Escape of Water
# 33                 Garden Plants
# 35                 Garden Plants
# 36               General Damages
# 44                  Ground Heave
# 54                      Hot Work
# 59                 House Removal
# 77   Malicious Acts or Vandalism
# 83            Personal Accidents
# 90              Trace and Access
# 91              Trace and Access
# 122                Vehicle Glass
# 134              Vehicle TheftVe
#
#                                                 header  \
# 5    Salma's home insurance covers "Emergency Damag...
# 19   Belinda's home insurance policy includes cover...
# 33   Margot has home insurance that covers "Garden ...
# 35   Margot has home insurance that covers "Garden ...
# 36   Gavin has an insurance policy that includes co...
# 44   Blake has home insurance that covers "Ground H...
# 54   Martha has an insurance policy that covers acc...
# 59   Denise's insurance covers damage from "House R...
# 77   Beth has home insurance that covers losses fro...
# 83   Penelope's car insurance policy includes cover...
# 90   Justin has insurance that covers "Trace and Ac...
# 91   Justin has insurance that covers "Trace and Ac...
# 122  Aneesh's car insurance policy includes coverag...
# 134  Cooper's car insurance policy includes coverag...
#
#                                           continuation  \
# 5    Late one night, Salma hears noises coming from...
# 19   Belinda lives in a two-story house with a bath...
# 33   One day, while Margot is away from her home, h...
# 35   One day, while Margot is away from her home, h...
# 36   Gavin works as an A/C repair technician in a s...
# 44   One evening, several of Blake's friends crowd ...
# 54   Martha is installing hardwood flooring in her ...
# 59   Denise is moving to a new home on the other si...
# 77   Beth lives in a very quiet neighborhood at the...
# 83   Penelope is a personal trainer, and on weekend...
# 90   Justin, a skilled plumber, is repairing his le...
# 91   Justin, a skilled plumber, is repairing his le...
# 122  Aneesh drives a convertible Porsche and parks ...
# 134  Cooper, who doesn't keep a GPS tracking device...
#
#                                               question  \
# 5    Out of 100 randomly-surveyed people, estimate ...
# 19   Out of 100 randomly-surveyed people, estimate ...
# 33   Out of 100 randomly-surveyed people, estimate ...
# 35   Out of 100 randomly-surveyed people, estimate ...
# 36   Out of 100 randomly-surveyed people, estimate ...
# 44   Out of 100 randomly-surveyed people, estimate ...
# 54   Out of 100 randomly-surveyed people, estimate ...
# 59   Out of 100 randomly-surveyed people, estimate ...
# 77   Out of 100 randomly-surveyed people, estimate ...
# 83   Out of 100 randomly-surveyed people, estimate ...
# 90   Out of 100 randomly-surveyed people, estimate ...
# 91   Out of 100 randomly-surveyed people, estimate ...
# 122  Out of 100 randomly-surveyed people, estimate ...
# 134  Out of 100 randomly-surveyed people, estimate ...
#
#                                                 prompt completion  index  \
# 5    Salma's home insurance covers "Emergency Damag...          7      5
# 19   Belinda's home insurance policy includes cover...         87     19
# 33   Margot has home insurance that covers "Garden ...         93     33
# 35   Margot has home insurance that covers "Garden ...         21     35
# 36   Gavin has an insurance policy that includes co...         23     36
# 44   Blake has home insurance that covers "Ground H...         17     44
# 54   Martha has an insurance policy that covers acc...         59     54
# 59   Denise's insurance covers damage from "House R...         21     59
# 77   Beth has home insurance that covers losses fro...          4     77
# 83   Penelope's car insurance policy includes cover...         48     83
# 90   Justin has insurance that covers "Trace and Ac...         71     90
# 91   Justin has insurance that covers "Trace and Ac...         73     91
# 122  Aneesh's car insurance policy includes coverag...          7    122
# 134  Cooper's car insurance policy includes coverag...          0    134
#
#     fineTunedPredictions
# 5                    100
# 19                   100
# 33                   100
# 35                   100
# 36                   100
# 44                   100
# 54                   100
# 59                   100
# 77                   100
# 83                   100
# 90                   100
# 91                   100
# 122                  100
# 134                  100

# %%
for i in range(0,1):
    print(i)
