# %%
import openai
import os
import pandas
import numpy as np
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
prompts = pandas.read_csv("stimuli.csv").query("avoid==False")
prompts.head(1)
# Out:
#                item               Title                version  \
# 0  Emergency Damage  Emergency Damage I  unambiguous_uncovered
#
#                                               header  avoid  \
# 0  Joanne's home insurance covers "Emergency Dama...  False
#
#                                         continuation name_gender  \
# 0  Late one night, Joanne hears noises coming fro...     female
#
#                         notes locus_of_uncertainty Unnamed: 9
# 0  dogs playing not emergency  perceived emergency        NaN

# %%
prompts.rename(columns={'Title':'title'}, inplace=True)
prompts["prompt"] = prompts.header + "\n" + prompts.continuation
prompts.rename(columns={'version':'completion'}, inplace=True)
prompts = prompts[["item","title","prompt","completion"]]
prompts.head(1)
# Out:
#                item               title  \
# 0  Emergency Damage  Emergency Damage I
#
#                                               prompt  \
# 0  Joanne's home insurance covers "Emergency Dama...
#
#                                         continuation
# 0  Late one night, Joanne hears noises coming fro...

# %%
# 37 items, so 25 is ~70% train and 12 is ~30% test
len(np.unique(prompts['title']))
# Out:
# 37

# %%
# Fine-tuning data. Note: right now, GPT-3 can only be fine-tuned on 'completion' tasks.
np.random.seed(44)
shuffledPrompts = sorted(prompts['item'], key = lambda x: np.random.rand())
trainItems = shuffledPrompts[0:25]
testItems = shuffledPrompts[25:37]

trainSet = prompts[prompts.item.isin(trainItems)]
testSet = prompts[prompts.item.isin(testItems)]
# Out:
#                 item               title  \
# 12   Escape of Water   Escape of Water I
# 13   Escape of Water   Escape of Water I
# 14   Escape of Water   Escape of Water I
# 15   Escape of Water  Escape of Water II
# 16   Escape of Water  Escape of Water II
# ..               ...                 ...
# 148    Vehicle Glass     Vehicle Glass I
# 149    Vehicle Glass     Vehicle Glass I
# 150    Vehicle Glass    Vehicle Glass II
# 151    Vehicle Glass    Vehicle Glass II
# 152    Vehicle Glass    Vehicle Glass II
#
#                                                 prompt  \
# 12   Carol's homeowner's insurance policy includes ...
# 13   Carol's homeowner's insurance policy includes ...
# 14   Carol's homeowner's insurance policy includes ...
# 15   Miranda's homeowner's insurance policy include...
# 16   Miranda's homeowner's insurance policy include...
# ..                                                 ...
# 148  Ahmad's car insurance policy includes coverage...
# 149  Ahmad's car insurance policy includes coverage...
# 150  Aneesh's car insurance policy includes coverag...
# 151  Aneesh's car insurance policy includes coverag...
# 152  Aneesh's car insurance policy includes coverag...
#
#                                           continuation
# 12   Carol discovers that her bathroom wall has bec...
# 13   Carol discovers that her bathroom wall has bec...
# 14   Carol discovers that her bathroom wall has bec...
# 15   Miranda lives in a two-story house, and she ke...
# 16   Miranda lives in a two-story house, and she ha...
# ..                                                 ...
# 148  Ahmad drives a convertible Porsche and parks h...
# 149  Ahmad drives a convertible Porsche and parks h...
# 150  Aneesh drives a convertible Porsche and parks ...
# 151  Aneesh drives a convertible Porsche and parks ...
# 152  Aneesh drives a convertible Porsche and parks ...
#
# [65 rows x 4 columns]

# %%
fineTuningData = (fineTuningData.assign(completion=["5 {{STOP}}","95 {{STOP}}"]))[["prompt","completion","suffix"]]
openai.File.create(
  file=fineTuningData.to_json(orient = "records", lines=True),
  purpose='fine-tune'
)

# %%
openai.FineTune.create(training_file="file-YxSIy798Py3YbYOvXf2Pt2gl", model = "davinci")
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Input In [393], in <cell line: 1>()
# ----> 1 openai.FineTune.create(training_file="file-YxSIy798Py3YbYOvXf2Pt2gl", model = "text-davinci-insert-001")
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/openai/api_resources/abstract/createable_api_resource.py:39, in CreateableAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#      36 else:
#      37     raise error.InvalidAPIType("Unsupported API type %s" % api_type)
# ---> 39 response, _, api_key = requestor.request(
#      40     "post", url, params, request_id=request_id
#      41 )
#      43 return util.convert_to_openai_object(
#      44     response,
#      45     api_key,
#    (...)
#      48     plain_old_data=cls.plain_old_data,
#      49 )
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/openai/api_requestor.py:181, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     160 def request(
#     161     self,
#     162     method,
#    (...)
#     169     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     170 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     171     result = self.request_raw(
#     172         method.lower(),
#     173         url,
#    (...)
#     179         request_timeout=request_timeout,
#     180     )
# --> 181     resp, got_stream = self._interpret_response(result, stream)
#     182     return resp, got_stream, self.api_key
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/openai/api_requestor.py:396, in APIRequestor._interpret_response(self, result, stream)
#     388     return (
#     389         self._interpret_response_line(
#     390             line, result.status_code, result.headers, stream=True
#     391         )
#     392         for line in parse_stream(result.iter_lines())
#     393     ), True
#     394 else:
#     395     return (
# --> 396         self._interpret_response_line(
#     397             result.content, result.status_code, result.headers, stream=False
#     398         ),
#     399         False,
#     400     )
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/openai/api_requestor.py:429, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     427 stream_error = stream and "error" in resp.data
#     428 if stream_error or not 200 <= rcode < 300:
# --> 429     raise self.handle_error_response(
#     430         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     431     )
#     432 return resp
#
# InvalidRequestError: Invalid base model: text-davinci-insert-001 (model must be one of ada, babbage, curie, davinci) or a fine-tuned model created by your organization: org-O1nE8SHl8ANRhiZJ3M17aIt6

# %%
openai.FineTune.list()
# Out:
# <OpenAIObject list at 0x12a323fb0> JSON: {
#   "data": [
#     {
#       "created_at": 1670224821,
#       "fine_tuned_model": "curie:ft-stanford-2022-12-05-07-23-36",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-Ynnt5qHkqeQbp3inH6WOwvkj",
#       "model": "curie",
#       "object": "fine-tune",
#       "organization_id": "org-O1nE8SHl8ANRhiZJ3M17aIt6",
#       "result_files": [
#         {
#           "bytes": 435,
#           "created_at": 1670225018,
#           "filename": "compiled_results.csv",
#           "id": "file-zAT6ZPDkWZRh64QXF3O0RjHw",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 1688,
#           "created_at": 1670224694,
#           "filename": "file",
#           "id": "file-nenODZw8KED9mSolTk7938m0",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1670225019,
#       "validation_files": []
#     },
#     {
#       "created_at": 1670225493,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-EpG5y7gCBzbW99fkrq4wU7gW",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-O1nE8SHl8ANRhiZJ3M17aIt6",
#       "result_files": [],
#       "status": "pending",
#       "training_files": [
#         {
#           "bytes": 1688,
#           "created_at": 1670224694,
#           "filename": "file",
#           "id": "file-nenODZw8KED9mSolTk7938m0",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1670225496,
#       "validation_files": []
#     }
#   ],
#   "object": "list"
# }

# %%
openai.FineTune.retrieve(id="ft-svkAuE87NX7uCinyp6hP800T")
# Out:
# <FineTune fine-tune id=ft-svkAuE87NX7uCinyp6hP800T at 0x12b899030> JSON: {
#   "created_at": 1670269670,
#   "events": [
#     {
#       "created_at": 1670269670,
#       "level": "info",
#       "message": "Created fine-tune: ft-svkAuE87NX7uCinyp6hP800T",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670269674,
#       "level": "info",
#       "message": "Fine-tune costs $0.04",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670269675,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670269904,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670269986,
#       "level": "info",
#       "message": "Completed epoch 1/4",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670269987,
#       "level": "info",
#       "message": "Completed epoch 2/4",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670269988,
#       "level": "info",
#       "message": "Completed epoch 3/4",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670269988,
#       "level": "info",
#       "message": "Completed epoch 4/4",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670270027,
#       "level": "info",
#       "message": "Uploaded model: davinci:ft-stanford-2022-12-05-19-53-46",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670270028,
#       "level": "info",
#       "message": "Uploaded result file: file-SHuVNOgnPwAAaY0h7hwJ4Tru",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670270028,
#       "level": "info",
#       "message": "Fine-tune succeeded",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": "davinci:ft-stanford-2022-12-05-19-53-46",
#   "hyperparams": {
#     "batch_size": 1,
#     "learning_rate_multiplier": 0.1,
#     "n_epochs": 4,
#     "prompt_loss_weight": 0.01
#   },
#   "id": "ft-svkAuE87NX7uCinyp6hP800T",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-O1nE8SHl8ANRhiZJ3M17aIt6",
#   "result_files": [
#     {
#       "bytes": 426,
#       "created_at": 1670270027,
#       "filename": "compiled_results.csv",
#       "id": "file-SHuVNOgnPwAAaY0h7hwJ4Tru",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "status": "succeeded",
#   "training_files": [
#     {
#       "bytes": 1752,
#       "created_at": 1670269652,
#       "filename": "file",
#       "id": "file-YxSIy798Py3YbYOvXf2Pt2gl",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670270028,
#   "validation_files": []
# }

# %%
finetunedGPT3Predictions = prompts.head(10)
finetunedGPT3Predictions["prediction"] = finetunedGPT3Predictions.apply(lambda x: openai.Completion.create(model="davinci:ft-stanford-2022-12-05-19-53-46", # davinci:ft-stanford-2022-12-05-19-53-46
                                    prompt=x["prompt"],
                                    #Only possible to fine-tune models on 'prompt' and 'completion' at this point; 'suffix' argument not revealed to fine-tuned davinci models                                                                      
                                    suffix=x["suffix"], 
                                    temperature=0, max_tokens=10).choices[0].text, axis=1 )
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Input In [394], in <cell line: 2>()
#       1 finetunedGPT3Predictions = prompts.head(10)
# ----> 2 finetunedGPT3Predictions["prediction"] = finetunedGPT3Predictions.apply(lambda x: openai.Completion.create(model="davinci:ft-stanford-2022-12-05-19-53-46", # davinci:ft-stanford-2022-12-05-19-53-46
#       3                                     prompt=x["prompt"],
#       4                                     #Only possible to fine-tune models on 'prompt' and 'completion' at this point; 'suffix' argument not revealed to fine-tuned davinci models
#       5                                     suffix=x["suffix"],
#       6                                     temperature=0, max_tokens=10).choices[0].text, axis=1 )
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/pandas/core/frame.py:9565, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9554 from pandas.core.apply import frame_apply
#    9556 op = frame_apply(
#    9557     self,
#    9558     func=func,
#    (...)
#    9563     kwargs=kwargs,
#    9564 )
# -> 9565 return op.apply().__finalize__(self, method="apply")
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/pandas/core/apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/pandas/core/apply.py:873, in FrameApply.apply_standard(self)
#     872 def apply_standard(self):
# --> 873     results, res_index = self.apply_series_generator()
#     875     # wrap results
#     876     return self.wrap_results(results, res_index)
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/pandas/core/apply.py:889, in FrameApply.apply_series_generator(self)
#     886 with option_context("mode.chained_assignment", None):
#     887     for i, v in enumerate(series_gen):
#     888         # ignore SettingWithCopy here in case the user mutates
# --> 889         results[i] = self.f(v)
#     890         if isinstance(results[i], ABCSeries):
#     891             # If we have a view on v, we need to make a copy because
#     892             #  series_generator will swap out the underlying data
#     893             results[i] = results[i].copy(deep=False)
#
# Input In [394], in <lambda>(x)
#       1 finetunedGPT3Predictions = prompts.head(10)
# ----> 2 finetunedGPT3Predictions["prediction"] = finetunedGPT3Predictions.apply(lambda x: openai.Completion.create(model="davinci:ft-stanford-2022-12-05-19-53-46", # davinci:ft-stanford-2022-12-05-19-53-46
#       3                                     prompt=x["prompt"],
#       4                                     #Only possible to fine-tune models on 'prompt' and 'completion' at this point; 'suffix' argument not revealed to fine-tuned davinci models
#       5                                     suffix=x["suffix"],
#       6                                     temperature=0, max_tokens=10).choices[0].text, axis=1 )
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/openai/api_resources/completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:115, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     107 requestor = api_requestor.APIRequestor(
#     108     api_key,
#     109     api_base=api_base,
#    (...)
#     112     organization=organization,
#     113 )
#     114 url = cls.class_url(engine, api_type, api_version)
# --> 115 response, _, api_key = requestor.request(
#     116     "post",
#     117     url,
#     118     params=params,
#     119     headers=headers,
#     120     stream=stream,
#     121     request_id=request_id,
#     122     request_timeout=request_timeout,
#     123 )
#     125 if stream:
#     126     # must be an iterator
#     127     assert not isinstance(response, OpenAIResponse)
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/openai/api_requestor.py:181, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     160 def request(
#     161     self,
#     162     method,
#    (...)
#     169     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     170 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     171     result = self.request_raw(
#     172         method.lower(),
#     173         url,
#    (...)
#     179         request_timeout=request_timeout,
#     180     )
# --> 181     resp, got_stream = self._interpret_response(result, stream)
#     182     return resp, got_stream, self.api_key
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/openai/api_requestor.py:396, in APIRequestor._interpret_response(self, result, stream)
#     388     return (
#     389         self._interpret_response_line(
#     390             line, result.status_code, result.headers, stream=True
#     391         )
#     392         for line in parse_stream(result.iter_lines())
#     393     ), True
#     394 else:
#     395     return (
# --> 396         self._interpret_response_line(
#     397             result.content, result.status_code, result.headers, stream=False
#     398         ),
#     399         False,
#     400     )
#
# File /usr/local/anaconda3/envs/falseConsensus/lib/python3.10/site-packages/openai/api_requestor.py:429, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     427 stream_error = stream and "error" in resp.data
#     428 if stream_error or not 200 <= rcode < 300:
# --> 429     raise self.handle_error_response(
#     430         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     431     )
#     432 return resp
#
# InvalidRequestError: Unrecognized request argument supplied: suffix

# %%
finetunedGPT3Predictions # not currently fine-tuned, just predictions of text-davinci-insert-001
# Out:
#                            item                           title  \
# 0               Escape of Water              Escape of Water I
# 1               Escape of Water              Escape of Water I
# 2              Escape of Water                Escape of Water I
# 3                 Vehicle Glass                 Vehicle Glass I
# 4                 Vehicle Glass                 Vehicle Glass I
# 5                 Vehicle Glass                Vehicle Glass I
# 6  Storm Damage and Maintenance  Storm Damage and Maintenance I
# 7  Storm Damage and Maintenance  Storm Damage and Maintenance I
# 8  Storm Damage and Maintenance  Storm Damage and Maintenance I
# 9               Vehicle Damage                 Vehicle Damage I
#
#                  version                                             prompt  \
# 0  unambiguous_uncovered  Carol's homeowner's insurance policy includes ...
# 1    unambiguous_covered  Carol's homeowner's insurance policy includes ...
# 2          controversial  Carol's homeowner's insurance policy includes ...
# 3  unambiguous_uncovered  Ahmad's car insurance policy includes coverage...
# 4    unambiguous_covered  Ahmad's car insurance policy includes coverage...
# 5          controversial  Ahmad's car insurance policy includes coverage...
# 6  unambiguous_uncovered  Tom's home insurance policy includes coverage ...
# 7    unambiguous_covered  Tom's home insurance policy includes coverage ...
# 8          controversial  Tom's home insurance policy includes coverage ...
# 9  unambiguous_uncovered  Jenny's car insurance policy includes coverage...
#
#                                               suffix prediction
# 0  of those polled would believe that the damage ...       99%
# 1  of those polled would believe that the damage ...       99%
# 2  of those polled would believe that the damage ...       99%
# 3  of those polled would believe that the damage ...       99%
# 4  of those polled would believe that the damage ...       99%
# 5  of those polled would believe that the damage ...       99%
# 6  of those polled would believe that the damage ...       98%
# 7  of those polled would believe that the damage ...       98%
# 8  of those polled would believe that the damage ...       98%
# 9  of those polled would believe that the damage ...       80%
